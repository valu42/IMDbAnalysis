# %%
import pandas as pd
import numpy as np

# %%
rating_data_fn = "rating_data.tsv"
basic_data_fn = "basic_data.tsv"
merged_fn = "merged.csv"

# %%
basic_dtypes = {"tconst": str, 
                "titleType": str, 
                "primaryTitle": str, 
                "originalTitle": str,
                "isAdult": str,
                "startYear": str,
                "endYear": str,
                "runtimeMinutes": str,
                "genres": str,
               }
ratings_dtypes = {
    "tconst": str,
    "averageRating": str,
    "numVotes": int,
}

basics_df = pd.read_csv(basic_data_fn, sep="\t", low_memory=False, dtype=basic_dtypes)
ratings_df = pd.read_csv(rating_data_fn, sep="\t", low_memory=False, dtype=ratings_dtypes)

# %%
merged = pd.merge(basics_df, ratings_df)

# %%
merged
# Out:
#             tconst  titleType                primaryTitle  \
# 0        tt0000001      short                  Carmencita
# 1        tt0000002      short      Le clown et ses chiens
# 2        tt0000003      short              Pauvre Pierrot
# 3        tt0000004      short                 Un bon bock
# 4        tt0000005      short            Blacksmith Scene
# ...            ...        ...                         ...
# 1274329  tt9916730      movie                      6 Gunn
# 1274330  tt9916766  tvEpisode              Episode #10.15
# 1274331  tt9916778  tvEpisode                      Escape
# 1274332  tt9916840  tvEpisode  Horrid Henry's Comic Caper
# 1274333  tt9916880  tvEpisode   Horrid Henry Knows It All
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                        Carmencita       0      1894      \N              1
# 1            Le clown et ses chiens       0      1892      \N              5
# ...

# %%
merged.to_csv(merged_fn, index=False)
